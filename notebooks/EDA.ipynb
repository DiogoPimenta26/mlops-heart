# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %load_ext kedro.ipython
# Out:
# [06/27/24 10:58:00] INFO     Registered line magic '%reload_kedro'                                   ]8;id=360148;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=854468;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py#51\51]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=374604;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=60864;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py#53\53]8;;\
#                     INFO     Resolved project path as: c:\Users\Admin_User\Desktop\mlops-heart.     ]8;id=897625;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=643557;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py#164\164]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [06/27/24 10:58:08] INFO     Registering new custom resolver: 'km.random_name'                    ]8;id=814812;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro_mlflow\framework\hooks\mlflow_hook.py\mlflow_hook.py]8;;\:]8;id=218328;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro_mlflow\framework\hooks\mlflow_hook.py#65\65]8;;\
#                     WARNING  No 'mlflow.yml' config file found in environment. Default            ]8;id=374820;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro_mlflow\framework\hooks\mlflow_hook.py\mlflow_hook.py]8;;\:]8;id=553326;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro_mlflow\framework\hooks\mlflow_hook.py#78\78]8;;\
#                              configuration will be used. Use ``kedro mlflow init`` command in CLI
#                              to customize the configuration.
#                     INFO     The 'tracking_uri' key in mlflow.yml is relative            ]8;id=217299;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro_mlflow\config\kedro_mlflow_config.py\kedro_mlflow_config.py]8;;\:]8;id=331023;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro_mlflow\config\kedro_mlflow_config.py#260\260]8;;\
#                              ('server.mlflow_(tracking|registry)_uri = mlruns'). It is
#                              converted to a valid uri:
#                              'file:///C:/Users/Admin_User/Desktop/mlops-heart/mlruns'
# [06/27/24 10:58:09] INFO     Kedro project mlops_heart                                              ]8;id=46915;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=619213;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py#134\134]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=392062;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=427936;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py#135\135]8;;\
#                              'pipelines'
# [06/27/24 10:58:18] INFO     Registered line magic 'run_viz'                                        ]8;id=139176;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=743398;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\ipython\__init__.py#141\141]8;;\

# %%
catalog
# Out:
# <kedro.io.data_catalog.DataCatalog object at 0x00000194454E3520>

# %%
df = catalog.load('heart_data_raw')
# Out:
#                     INFO     Loading data from heart_data_raw (CSVDataset)...                   ]8;id=961925;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=988611;file://c:\Users\Admin_User\anaconda3\envs\test_env\lib\site-packages\kedro\io\data_catalog.py#483\483]8;;\

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe().T
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>age</th>
#       <td>1190.0</td>
#       <td>53.720168</td>
#       <td>9.358203</td>
#       <td>28.0</td>
#       <td>47.0</td>
#       <td>54.0</td>
#       <td>60.00</td>
#       <td>77.0</td>
#     </tr>
#     <tr>
#       <th>sex</th>
#       <td>1190.0</td>
#       <td>0.763866</td>
#       <td>0.424884</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.00</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>chest_pain_type</th>
#       <td>1190.0</td>
#       <td>3.232773</td>
#       <td>0.935480</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>4.00</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>resting_bp_s</th>
#       <td>1190.0</td>
#       <td>132.153782</td>
#       <td>18.368823</td>
#       <td>0.0</td>
#       <td>120.0</td>
#       <td>130.0</td>
#       <td>140.00</td>
#       <td>200.0</td>
#     </tr>
#     <tr>
#       <th>cholesterol</th>
#       <td>1190.0</td>
#       <td>210.363866</td>
#       <td>101.420489</td>
#       <td>0.0</td>
#       <td>188.0</td>
#       <td>229.0</td>
#       <td>269.75</td>
#       <td>603.0</td>
#     </tr>
#     <tr>
#       <th>fasting_blood_sugar</th>
#       <td>1190.0</td>
#       <td>0.213445</td>
#       <td>0.409912</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>resting_ecg</th>
#       <td>1190.0</td>
#       <td>0.698319</td>
#       <td>0.870359</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.00</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>max_heart_rate</th>
#       <td>1190.0</td>
#       <td>139.732773</td>
#       <td>25.517636</td>
#       <td>60.0</td>
#       <td>121.0</td>
#       <td>140.5</td>
#       <td>160.00</td>
#       <td>202.0</td>
#     </tr>
#     <tr>
#       <th>exercise_angina</th>
#       <td>1190.0</td>
#       <td>0.387395</td>
#       <td>0.487360</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.00</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>oldpeak</th>
#       <td>1190.0</td>
#       <td>0.922773</td>
#       <td>1.086337</td>
#       <td>-2.6</td>
#       <td>0.0</td>
#       <td>0.6</td>
#       <td>1.60</td>
#       <td>6.2</td>
#     </tr>
#     <tr>
#       <th>st_slope</th>
#       <td>1190.0</td>
#       <td>1.624370</td>
#       <td>0.610459</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.00</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>target</th>
#       <td>1190.0</td>
#       <td>0.528571</td>
#       <td>0.499393</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.00</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.dtypes
# Out:
# age                      int64
# sex                      int64
# chest_pain_type          int64
# resting_bp_s             int64
# cholesterol              int64
# fasting_blood_sugar      int64
# resting_ecg              int64
# max_heart_rate           int64
# exercise_angina          int64
# oldpeak                float64
# st_slope                 int64
# target                   int64
# dtype: object

# %%
#Checking unique values of all of the columns
for col in df.columns:
    print(col)
    print(df[col].unique())
    print('-----------------------------')
# Out:
# age
# [40 49 37 48 54 39 45 58 42 38 43 60 36 44 53 52 51 56 41 32 65 35 59 50
#  47 31 46 57 55 63 66 34 33 61 29 62 28 30 74 68 72 64 69 67 73 70 77 75
#  76 71]
# -----------------------------
# sex
# [1 0]
# -----------------------------
# chest_pain_type
# [2 3 4 1]
# -----------------------------
# resting_bp_s
# [140 160 130 138 150 120 110 136 115 100 124 113 125 145 112 132 118 170
#  142 190 135 180 108 155 128 106  92 200 122  98 105 133  95  80 137 185
#  165 126 152 116   0 144 154 134 104 139 131 141 178 146 158 123 102  96
#  143 172 156 114 127 101 174  94 148 117 192 129 164]
# -----------------------------
# cholesterol
# [289 180 283 214 195 339 237 208 207 284 211 164 204 234 273 196 201 248
#  267 223 184 288 215 209 260 468 188 518 167 224 172 186 254 306 250 177
#  227 230 294 264 259 175 318 216 340 233 205 245 194 270 213 365 342 253
#  277 202 297 225 246 412 265 182 218 268 163 529 100 206 238 139 263 291
#  229 307 210 329 147  85 269 275 179 392 466 129 241 255 276 282 338 160
#  156 272 240 393 161 228 292 388 166 247 331 341 243 279 198 249 168 603
#  159 190 185 290 212 231 222 235 320 187 266 287 404 312 251 328 285 280
#  192 193 308 219 257 132 226 217 303 298 256 117 295 173 315 281 309 200
#  336 355 326 171 491 271 274 394 221 126 305 220 242 347 344 358 169 181
#    0 236 203 153 316 311 252 458 384 258 349 142 197 113 261 310 232 110
#  123 170 369 152 244 165 337 300 333 385 322 564 239 293 407 149 199 417
#  178 319 354 330 302 313 141 327 304 286 360 262 325 299 409 174 183 321
#  353 335 278 157 176 131]
# -----------------------------
# fasting_blood_sugar
# [0 1]
# -----------------------------
# resting_ecg
# [0 1 2]
# -----------------------------
# max_heart_rate
# [172 156  98 108 122 170 142 130 120  99 145 140 137 150 166 165 125 160
#  164 138 178 112 118 127 114 154 155  87 148 100 168 184 121 153 134  96
#  174 175 144  82 135 115 128 116  94 110  92 180 152 124 106 185 139 190
#  146 158 132 176 119 188 162 105  90 136 167 129 102 143 103  91 126  93
#  131 149 123 182 141  77 109 133 179 113 104  95  72  97 117  86  63 157
#   83  60  70 163  67  78  84 111  80 107 161  69  88  73 159 151 181 186
#  177 173 169 171 147  71 192 195 194 187 202]
# -----------------------------
# exercise_angina
# [0 1]
# -----------------------------
# oldpeak
# [ 0.   1.   1.5  2.   3.   4.   0.5  2.5  5.   0.8  0.7  1.4  2.1  0.4
#   0.2  1.7  2.2  0.1  1.6  1.3  0.3  1.8  2.6 -0.9  2.8 -2.6 -1.5 -0.1
#   0.9  1.1  2.4 -1.  -1.1 -0.7 -0.8  3.7  1.2 -0.5 -2.   1.9  3.5  0.6
#   3.1  2.3  3.4  3.6  4.2  3.2  5.6  3.8  2.9  6.2  4.4]
# -----------------------------
# st_slope
# [1 2 3 0]
# -----------------------------
# target
# [0 1]
# -----------------------------

# %%
# Existe um caso que os BPM é 0, o que não faz sentido, então temos que remover

# %%
df.isna().sum()
# Out:
# age                    0
# sex                    0
# chest_pain_type        0
# resting_bp_s           0
# cholesterol            0
# fasting_blood_sugar    0
# resting_ecg            0
# max_heart_rate         0
# exercise_angina        0
# oldpeak                0
# st_slope               0
# target                 0
# dtype: int64

# %%
#Checking if the data is balanced
df['target'].value_counts()
# The data is balanced
# Out:
# 1    629
# 0    561
# Name: target, dtype: int64

# %%
# code from https://www.kaggle.com/code/revypramana/heart-disease-xgboost-96-64
cols = ['age', 'sex', 'chest_pain_type', 'resting_bp_s',
    'cholesterol', 'fasting_blood_sugar', 'resting_ecg', 
       'max_heart_rate', 'exercise_angina', 'oldpeak', 'st_slope']

for i, column in enumerate(cols, 1):
    plt.figure(figsize=(15, 5))
    
    # Create histogram on the left side
    plt.subplot(1, 2, 1)
    sns.histplot(data=df, x=column, kde=True)
    plt.title(f'Distribution of {column}')
    
    # Create boxplot on the right side
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    
    plt.show()

# %% [markdown]
# # Checking for data quality and fixing issues

# %%
df.duplicated().sum()
# Out:
# 272

# %%
# See the duplicated rows
df[df.duplicated()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>chest_pain_type</th>
#       <th>resting_bp_s</th>
#       <th>cholesterol</th>
#       <th>fasting_blood_sugar</th>
#       <th>resting_ecg</th>
#       <th>max_heart_rate</th>
#       <th>exercise_angina</th>
#       <th>oldpeak</th>
#       <th>st_slope</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>163</th>
#       <td>49</td>
#       <td>0</td>
#       <td>2</td>
#       <td>110</td>
#       <td>208</td>
#       <td>0</td>
#       <td>0</td>
#       <td>160</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>604</th>
#       <td>58</td>
#       <td>1</td>
#       <td>3</td>
#       <td>150</td>
#       <td>219</td>
#       <td>0</td>
#       <td>1</td>
#       <td>118</td>
#       <td>1</td>
#       <td>0.0</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>887</th>
#       <td>63</td>
#       <td>1</td>
#       <td>1</td>
#       <td>145</td>
#       <td>233</td>
#       <td>1</td>
#       <td>2</td>
#       <td>150</td>
#       <td>0</td>
#       <td>2.3</td>
#       <td>3</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>888</th>
#       <td>67</td>
#       <td>1</td>
#       <td>4</td>
#       <td>160</td>
#       <td>286</td>
#       <td>0</td>
#       <td>2</td>
#       <td>108</td>
#       <td>1</td>
#       <td>1.5</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>889</th>
#       <td>67</td>
#       <td>1</td>
#       <td>4</td>
#       <td>120</td>
#       <td>229</td>
#       <td>0</td>
#       <td>2</td>
#       <td>129</td>
#       <td>1</td>
#       <td>2.6</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1156</th>
#       <td>42</td>
#       <td>1</td>
#       <td>3</td>
#       <td>130</td>
#       <td>180</td>
#       <td>0</td>
#       <td>0</td>
#       <td>150</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1157</th>
#       <td>61</td>
#       <td>1</td>
#       <td>4</td>
#       <td>140</td>
#       <td>207</td>
#       <td>0</td>
#       <td>2</td>
#       <td>138</td>
#       <td>1</td>
#       <td>1.9</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1158</th>
#       <td>66</td>
#       <td>1</td>
#       <td>4</td>
#       <td>160</td>
#       <td>228</td>
#       <td>0</td>
#       <td>2</td>
#       <td>138</td>
#       <td>0</td>
#       <td>2.3</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1159</th>
#       <td>46</td>
#       <td>1</td>
#       <td>4</td>
#       <td>140</td>
#       <td>311</td>
#       <td>0</td>
#       <td>0</td>
#       <td>120</td>
#       <td>1</td>
#       <td>1.8</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1160</th>
#       <td>71</td>
#       <td>0</td>
#       <td>4</td>
#       <td>112</td>
#       <td>149</td>
#       <td>0</td>
#       <td>0</td>
#       <td>125</td>
#       <td>0</td>
#       <td>1.6</td>
#       <td>2</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>272 rows × 12 columns</p>
# </div>

# %%
def remove_duplicates(df):
    df = df.drop_duplicates()
    return df

# %%
df = remove_duplicates(df)
df.duplicated().sum()
# Out:
# 0

# %%
# Ver missing values
df.isna().sum()
#não tem
# Out:
# age                    0
# sex                    0
# chest_pain_type        0
# resting_bp_s           0
# cholesterol            0
# fasting_blood_sugar    0
# resting_ecg            0
# max_heart_rate         0
# exercise_angina        0
# oldpeak                0
# st_slope               0
# target                 0
# dtype: int64

# %%
df['resting_ecg'].value_counts()
# Out:
# 0    552
# 2    188
# 1    178
# Name: resting_ecg, dtype: int64

# %%
# Ver instancia em que o BPM é 0
df[df['resting_bp_s'] == 0]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      age  sex  chest pain type  resting bp s  cholesterol  \
# 450   55    1                3             0            0
#
#      fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 450                    0            0             155                0
#
#      oldpeak  ST slope  target
# 450      1.5         2       1

# %%
# Remove the row where the resting bp s is 0 in a function
def remove_zero_bp(df):
    df = df[df['resting_bp_s'] != 0]
    return df

# Remove the row where the resting bp s is 0
df = remove_zero_bp(df)

# %%
# Remove rows where cholesterol is 0
def remove_zero_cholesterol(df):
    df = df[df['cholesterol'] != 0]
    return df

df = remove_zero_cholesterol(df)

# %%
# Maximum heart rate should be between 72 and 202

def max_heart_rate_outliers(df):
    df = df[(df['max_heart_rate'] >= 72) & (df['max_heart_rate'] <= 202)]
    return df

df = max_heart_rate_outliers(df)

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# 2                       0            1              98                0
# 3                       0            0             108                1
# 4                       0            0             122                0
# ...                   ...          ...             ...              ...
# 1185                    0            0             132                0
# 1186                    1            0             141                0
# 1187                    0            0             115                1
# 1188                    0            2             174                0
# 1189                    0            0             173                0
#
#       oldpeak  ST slope  target
# 0         0.0         1       0
# 1         1.0         2       1
# 2         0.0         1       0
# 3         1.5         2       1
# 4         0.0         1       0
# ...       ...       ...     ...
# 1185      1.2         2       1
# 1186      3.4         2       1
# 1187      1.2         2       1
# 1188      0.0         2       1
# 1189      0.0         1       0
#
# [744 rows x 12 columns]

# %%
# Bin the age column

def bin_age(df):
    df['age'] = pd.cut(df['age'], bins=[0, 40, 50, 60, 70, 80, 90], labels=['0-40', '41-50', '51-60', '61-70', '71-80', '81-90'])
    return df

df = bin_age(df)

# %%
#bin the cholesterol column into three categories
def bin_cholesterol(df):
    df['cholesterol'] = pd.cut(df['cholesterol'], bins=[0, 200, 240, 1000], labels=['normal', 'borderline high', 'high'])
    return df

df = bin_cholesterol(df)

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>chest_pain_type</th>
#       <th>resting_bp_s</th>
#       <th>cholesterol</th>
#       <th>fasting_blood_sugar</th>
#       <th>resting_ecg</th>
#       <th>max_heart_rate</th>
#       <th>exercise_angina</th>
#       <th>oldpeak</th>
#       <th>st_slope</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0-40</td>
#       <td>1</td>
#       <td>2</td>
#       <td>140</td>
#       <td>high</td>
#       <td>0</td>
#       <td>0</td>
#       <td>172</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>41-50</td>
#       <td>0</td>
#       <td>3</td>
#       <td>160</td>
#       <td>normal</td>
#       <td>0</td>
#       <td>0</td>
#       <td>156</td>
#       <td>0</td>
#       <td>1.0</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0-40</td>
#       <td>1</td>
#       <td>2</td>
#       <td>130</td>
#       <td>high</td>
#       <td>0</td>
#       <td>1</td>
#       <td>98</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>41-50</td>
#       <td>0</td>
#       <td>4</td>
#       <td>138</td>
#       <td>borderline high</td>
#       <td>0</td>
#       <td>0</td>
#       <td>108</td>
#       <td>1</td>
#       <td>1.5</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>51-60</td>
#       <td>1</td>
#       <td>3</td>
#       <td>150</td>
#       <td>normal</td>
#       <td>0</td>
#       <td>0</td>
#       <td>122</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1185</th>
#       <td>41-50</td>
#       <td>1</td>
#       <td>1</td>
#       <td>110</td>
#       <td>high</td>
#       <td>0</td>
#       <td>0</td>
#       <td>132</td>
#       <td>0</td>
#       <td>1.2</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1186</th>
#       <td>61-70</td>
#       <td>1</td>
#       <td>4</td>
#       <td>144</td>
#       <td>normal</td>
#       <td>1</td>
#       <td>0</td>
#       <td>141</td>
#       <td>0</td>
#       <td>3.4</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1187</th>
#       <td>51-60</td>
#       <td>1</td>
#       <td>4</td>
#       <td>130</td>
#       <td>normal</td>
#       <td>0</td>
#       <td>0</td>
#       <td>115</td>
#       <td>1</td>
#       <td>1.2</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1188</th>
#       <td>51-60</td>
#       <td>0</td>
#       <td>2</td>
#       <td>130</td>
#       <td>borderline high</td>
#       <td>0</td>
#       <td>2</td>
#       <td>174</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1189</th>
#       <td>0-40</td>
#       <td>1</td>
#       <td>3</td>
#       <td>138</td>
#       <td>normal</td>
#       <td>0</td>
#       <td>0</td>
#       <td>173</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>918 rows × 12 columns</p>
# </div>
